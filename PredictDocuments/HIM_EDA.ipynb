# %%
import os
import pandas as pd
import pandas_profiling as pp
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as ss
import seaborn as sns
import matplotlib.pyplot as plt

# %%
him=pd.read_csv('him_enc_orders_030319_031019_2.csv', encoding='cp1252')

# %%
# cleaning text
him.columns = him.columns.str.lower()
# him = him.apply(lambda x: x.astype(str).str.lower())

# %%
him
# Out:
#           person_id    encntr_id     encntr_type_cd encntr_type_class_cd  \
# 0         1416312.0  161637289.0  Clinic Non Office           Outpatient
# 1         1416312.0  163857986.0  Clinic Non Office           Outpatient
# 2         2339494.0  161614840.0  Clinic Non Office           Outpatient
# 3         2516380.0  160129514.0  Clinic Non Office           Outpatient
# 4         4198468.0  159037614.0  Clinic Non Office           Outpatient
# 5         4426756.0  158970545.0             Clinic           Outpatient
# 6         5018843.0  159092611.0  Clinic Non Office           Outpatient
# 7         5018843.0  159096157.0  Clinic Non Office           Outpatient
# 8         5018843.0  159098018.0  Clinic Non Office           Outpatient
# 9         5018843.0  159115876.0  Clinic Non Office           Outpatient
# 10        5076412.0  160158989.0  Clinic Non Office           Outpatient
# 11        8716437.0  160124765.0  Clinic Non Office           Outpatient
# ...

# %%
him_profile=pp.ProfileReport(him)
# him_profile.to_file(r"him_profile.html")
